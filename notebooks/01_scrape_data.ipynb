# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from src.scraper import second_diff, shot_scraper, get_game_ids, shot_scraper2

# %%
import pandas as pd
from nhlpy import NHLClient
from pathlib import Path

# %%
client = NHLClient()

# %%
games_2025 = get_game_ids()
games_2024 = get_game_ids([20232024])
games_2023 = get_game_ids([20222023])

# %%
client.game_center.play_by_play(2024020705)["rosterSpots"]
# Out:
# [{'teamId': 12,
#   'playerId': 8470613,
#   'firstName': {'default': 'Brent'},
#   'lastName': {'default': 'Burns'},
#   'sweaterNumber': 8,
#   'positionCode': 'D',
#   'headshot': 'https://assets.nhle.com/mugs/nhl/20242025/CAR/8470613.png'},
#  {'teamId': 7,
#   'playerId': 8473503,
#   'firstName': {'default': 'James'},
#   'lastName': {'default': 'Reimer'},
#   'sweaterNumber': 47,
#   'positionCode': 'G',
#   'headshot': 'https://assets.nhle.com/mugs/nhl/20242025/BUF/8473503.png'},
#  {'teamId': 12,
#   'playerId': 8473533,
#   'firstName': {'default': 'Jordan'},
#   'lastName': {'default': 'Staal'},
#   'sweaterNumber': 11,
#   'positionCode': 'C',
#   'headshot': 'https://assets.nhle.com/mugs/nhl/20242025/CAR/8473533.png'},
#  {'teamId': 12,
#   'playerId': 8474682,
#   'firstName': {'default': 'Dustin'},
#   'lastName': {'default': 'Tokarski'},
#   'sweaterNumber': 34,
#   'positionCode': 'G',
#   'headshot': 'https://assets.nhle.com/mugs/nhl/20242025/CAR/8474682.png'},
# ...

# %%
game_ids=[2024020705]
test = shot_scraper(game_ids)

# %%
test = shot_scraper(game_ids)

# %%
test2 = shot_scraper2(game_ids)

# %%
test3 = shot_scraper2([2024020706])

# %%
test
# Out:
#         game_id  team_id  home     last_play  rebound  rush home_skaters  \
# 0    2024020705        7     1       faceoff        0     0            5
# 1    2024020705        7     1  blocked-shot        0     0            5
# 2    2024020705        7     1           hit        0     0            5
# 3    2024020705        7     1      giveaway        0     0            5
# 4    2024020705        7     1  shot-on-goal        0     0            5
# ..          ...      ...   ...           ...      ...   ...          ...
# 96   2024020705       12     0           hit        0     0            5
# 97   2024020705       12     0       faceoff        0     0            5
# 98   2024020705       12     0   missed-shot        0     0            5
# 99   2024020705       12     0  shot-on-goal        0     0            5
# 100  2024020705       12     0  blocked-shot        1     0            5
#
#     away_skaters  x_coord  y_coord  ...  position shoots career_shooting_pct  \
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   game_id              101 non-null    int64
#  1   team_id              101 non-null    int64
#  2   home                 101 non-null    int64
#  3   last_play            101 non-null    object
#  4   rebound              101 non-null    int64
#  5   rush                 101 non-null    int64
#  6   home_skaters         101 non-null    object
#  7   away_skaters         101 non-null    object
#  8   x_coord              101 non-null    int64
#  9   y_coord              101 non-null    int64
#  10  shooter_id           101 non-null    int64
#  11  shooter              101 non-null    object
#  12  position             101 non-null    object
#  13  shoots               101 non-null    object
#  14  career_shooting_pct  101 non-null    float64
# ...

# %%
shots_2025 = shot_scraper2(games_2025)

# %%
shots_2025
# Out:
#            game_id  team_id  home     last_play  rebound  rush home_skaters  \
# 0       2024020008       52     0           hit        0     0            5
# 1       2024020008       52     0       faceoff        0     0            5
# 2       2024020008       22     1           hit        0     0            5
# 3       2024020008       52     0  shot-on-goal        0     0            5
# 4       2024020008       22     1       faceoff        0     0            5
# ...            ...      ...   ...           ...      ...   ...          ...
# 198626  2024021168       28     1  shot-on-goal        0     0            5
# 198627  2024021168        3     0           hit        0     0            5
# 198628  2024021168        3     0  blocked-shot        0     0            5
# 198629  2024021168        3     0      giveaway        0     0            5
# 198630  2024021168        3     0  shot-on-goal        0     0            5
#
# ...

# %%
shots_2024 = shot_scraper2(games_2024)

# %%
shots_2023 = shot_scraper2(games_2023)

# %%
shots_2024["shooter"].value_counts()
# Out:
# shooter
# David Pastrnak      1184
# Nathan MacKinnon    1176
# Auston Matthews     1142
# Filip Forsberg      1060
# Zach Hyman          1048
#                     ...
# Cole McWard            2
# Declan Carlile         2
# Glenn Gawdin           2
# Anthony Stolarz        2
# Gage Goncalves         2
# Name: count, Length: 907, dtype: int64

# %%
shots_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243816 entries, 0 to 243815
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   game_id       243816 non-null  int64
#  1   team_id       243816 non-null  int64
#  2   home          243816 non-null  int64
#  3   last_play     243816 non-null  object
#  4   rebound       243816 non-null  int64
#  5   rush          243816 non-null  int64
#  6   home_skaters  243816 non-null  object
#  7   away_skaters  243816 non-null  object
#  8   x_coord       243816 non-null  int64
#  9   y_coord       243816 non-null  int64
#  10  shooter_id    243816 non-null  int64
#  11  shooter       243816 non-null  object
#  12  goalie_id     243816 non-null  int64
#  13  goalie        243816 non-null  object
#  14  shot_type     243816 non-null  object
#  15  zone          243816 non-null  object
#  16  shot_class    243816 non-null  object
# dtypes: int64(9), object(8)
# ...

# %%
shots_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244558 entries, 0 to 244557
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   game_id       244558 non-null  int64
#  1   team_id       244558 non-null  int64
#  2   home          244558 non-null  int64
#  3   last_play     244558 non-null  object
#  4   rebound       244558 non-null  int64
#  5   rush          244558 non-null  int64
#  6   home_skaters  244558 non-null  object
#  7   away_skaters  244558 non-null  object
#  8   x_coord       244558 non-null  int64
#  9   y_coord       244558 non-null  int64
#  10  shooter_id    244558 non-null  int64
#  11  shooter       244558 non-null  object
#  12  goalie_id     244558 non-null  int64
#  13  goalie        244558 non-null  object
#  14  shot_type     244558 non-null  object
#  15  zone          244558 non-null  object
#  16  shot_class    244558 non-null  object
# dtypes: int64(9), object(8)
# ...

# %%
shots_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198631 entries, 0 to 198630
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   game_id       198631 non-null  int64
#  1   team_id       198631 non-null  int64
#  2   home          198631 non-null  int64
#  3   last_play     198631 non-null  object
#  4   rebound       198631 non-null  int64
#  5   rush          198631 non-null  int64
#  6   home_skaters  198631 non-null  object
#  7   away_skaters  198631 non-null  object
#  8   x_coord       198631 non-null  int64
#  9   y_coord       198631 non-null  int64
#  10  shooter_id    198631 non-null  int64
#  11  shooter       198631 non-null  object
#  12  goalie_id     198631 non-null  int64
#  13  goalie        198631 non-null  object
#  14  shot_type     198631 non-null  object
#  15  zone          198631 non-null  object
#  16  shot_class    198631 non-null  object
# dtypes: int64(9), object(8)
# ...

# %%
shots_2025.isna().sum()
# Out:
# game_id         0
# team_id         0
# home            0
# last_play       0
# rebound         0
# rush            0
# home_skaters    0
# away_skaters    0
# x_coord         0
# y_coord         0
# shooter_id      0
# shooter         0
# goalie_id       0
# goalie          0
# shot_type       0
# zone            0
# shot_class      0
# dtype: int64

# %%
shots_2024.isna().sum()
# Out:
# game_id         0
# team_id         0
# home            0
# last_play       0
# rebound         0
# rush            0
# home_skaters    0
# away_skaters    0
# x_coord         0
# y_coord         0
# shooter_id      0
# shooter         0
# goalie_id       0
# goalie          0
# shot_type       0
# zone            0
# shot_class      0
# dtype: int64

# %%
shots_2023.isna().sum()
# Out:
# game_id         0
# team_id         0
# home            0
# last_play       0
# rebound         0
# rush            0
# home_skaters    0
# away_skaters    0
# x_coord         0
# y_coord         0
# shooter_id      0
# shooter         0
# goalie_id       0
# goalie          0
# shot_type       0
# zone            0
# shot_class      0
# dtype: int64

# %%
path2025 = Path('..') / 'data' / 'raw' / 'shots_2025.parquet'
path2024 = Path('..') / 'data' / 'raw' / 'shots_2024.parquet'
path2023 = Path('..') / 'data' / 'raw' / 'shots_2023.parquet'

shots_2025.to_parquet(path=path2025, engine="pyarrow")
shots_2024.to_parquet(path=path2024, engine="pyarrow")
shots_2023.to_parquet(path=path2023, engine="pyarrow")
