# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import numpy as np
import pandas as pd
from nhlpy import NHLClient
from pathlib import Path
import pyarrow

# %%
client = NHLClient()

# %%
path2025 = Path('..') / 'data' / 'raw' / 'shots_2025.parquet'
path2024 = Path('..') / 'data' / 'raw' / 'shots_2024.parquet'
path2023 = Path('..') / 'data' / 'raw' / 'shots_2023.parquet'

# %%
shots_2025 = pd.read_parquet(path2025, engine="pyarrow")
shots_2024 = pd.read_parquet(path2024, engine="pyarrow")
shots_2023 = pd.read_parquet(path2023, engine="pyarrow")

# %%
shots_2025
# Out:
#            game_id  team_id  home     last_play  rebound  rush home_skaters  \
# 0       2024020008       52     0           hit        0     0            5
# 1       2024020008       52     0       faceoff        0     0            5
# 2       2024020008       22     1           hit        0     0            5
# 3       2024020008       52     0  shot-on-goal        0     0            5
# 4       2024020008       22     1       faceoff        0     0            5
# ...            ...      ...   ...           ...      ...   ...          ...
# 198626  2024021168       28     1  shot-on-goal        0     0            5
# 198627  2024021168        3     0           hit        0     0            5
# 198628  2024021168        3     0  blocked-shot        0     0            5
# 198629  2024021168        3     0      giveaway        0     0            5
# 198630  2024021168        3     0  shot-on-goal        0     0            5
#
#        away_skaters  x_coord  y_coord  shooter_id         shooter  goalie_id  \
# 0                 5       70        4     8476460  Mark Scheifele    8479973
# 1                 5       54      -21     8477504  Josh Morrissey    8479973
# 2                 5       68       -8     8477015    Connor Brown    8476945
# 3                 5       53      -31     8482149   Cole Perfetti    8479973
# 4                 5       58      -22     8477934  Leon Draisaitl    8476945
# ...             ...      ...      ...         ...             ...        ...
# 198626            4       62      -16     8483481        Cam Lund    8471734
# 198627            5       47       29     8479323        Adam Fox    8480382
# 198628            5       88       29     8479323        Adam Fox    8480382
# 198629            5       71      -42     8482132    Brett Berard    8480382
# 198630            5       63       36     8479323        Adam Fox    8480382
#
#                     goalie shot_type zone    shot_class
# 0           Stuart Skinner     wrist    O  shot-on-goal
# 1           Stuart Skinner      snap    O   missed-shot
# 2        Connor Hellebuyck    tip-in    O  shot-on-goal
# 3           Stuart Skinner      snap    O  shot-on-goal
# 4        Connor Hellebuyck      snap    O  shot-on-goal
# ...                    ...       ...  ...           ...
# 198626      Jonathan Quick     wrist    O          goal
# 198627  Alexandar Georgiev      slap    O  shot-on-goal
# 198628  Alexandar Georgiev     wrist    O   missed-shot
# 198629  Alexandar Georgiev     wrist    O  shot-on-goal
# 198630  Alexandar Georgiev     wrist    O  shot-on-goal
#
# [198631 rows x 17 columns]

# %%
shooter_ids2025 = shots_2025["shooter_id"].tolist()

# %%
test_dict = client.stats.player_career_stats(8479973)
test_dict["position"]
test_dict["shootsCatches"]
test_dict["featuredStats"]["regularSeason"]["career"]
# Out:
# {'gamesPlayed': 172,
#  'goalsAgainstAvg': 2.756668,
#  'losses': 54,
#  'otLosses': 14,
#  'savePctg': 0.90529,
#  'shutouts': 6,
#  'wins': 96}

# %%
stats2025 = []
stats_dict = {}
for id in shooter_ids2025:
    if id not in stats_dict.keys():
        stats = client.stats.player_career_stats(id)
        try:
            stats_dict[id] = {
                "position": stats["position"],
                "hand": stats["shootsCatches"],
                "pct": stats["featuredStats"]["regularSeason"]["career"]["shootingPctg"]
                }
        except:
            stats_dict[id] = {
                "position": stats["position"],
                "hand": stats["shootsCatches"],
                "pct": None
                }

    position = stats_dict[id]["position"]
    shooter_hand = stats_dict[id]["hand"]
    shooting_pct = stats_dict[id]["pct"]
    stats2025.append((position, shooter_hand, shooting_pct))

# %%
len(stats2025)
# Out:
# 198631

# %%
header = ["position", "shooter_hand", "shooting_pct"]
stats2025_df = pd.DataFrame(stats2025, columns=header)

# %%
goalie_ids2025 = shots_2025["goalie_id"].tolist()

# %%
goalie_stats2025 = []
goalie_stats_dict = {}
for id in goalie_ids2025:
    if id not in goalie_stats_dict.keys():
        stats = client.stats.player_career_stats(id)
        try:
            goalie_stats_dict[id] = {
                "hand": stats["shootsCatches"],
                "pct": stats["featuredStats"]["regularSeason"]["career"]["savePctg"]
                }
        except:
            goalie_stats_dict[id] = {
                "hand": stats["shootsCatches"],
                "pct": None
                }

    shooter_hand = goalie_stats_dict[id]["hand"]
    save_pct = goalie_stats_dict[id]["pct"]
    goalie_stats2025.append((shooter_hand, save_pct))

# %%
goalie_header = ["glove_hand", "save_pct"]
goalie_stats2025_df = pd.DataFrame(goalie_stats2025, columns=goalie_header)

# %%
goalie_stats2025_df
# Out:
#        glove_hand  save_pct
# 0               L  0.905290
# 1               L  0.905290
# 2               L  0.917540
# 3               L  0.905290
# 4               L  0.917540
# ...           ...       ...
# 198626          L  0.910698
# 198627          L  0.903763
# 198628          L  0.903763
# 198629          L  0.903763
# 198630          L  0.903763
#
# [198631 rows x 2 columns]

# %%
complete_df2025 = pd.concat([shots_2025, stats2025_df, goalie_stats2025_df], axis=1)
complete_df2025.head()
# Out:
#       game_id  team_id  home     last_play  rebound  rush home_skaters  \
# 0  2024020008       52     0           hit        0     0            5
# 1  2024020008       52     0       faceoff        0     0            5
# 2  2024020008       22     1           hit        0     0            5
# 3  2024020008       52     0  shot-on-goal        0     0            5
# 4  2024020008       22     1       faceoff        0     0            5
#
#   away_skaters  x_coord  y_coord  ...  goalie_id             goalie  \
# 0            5       70        4  ...    8479973     Stuart Skinner
# 1            5       54      -21  ...    8479973     Stuart Skinner
# 2            5       68       -8  ...    8476945  Connor Hellebuyck
# 3            5       53      -31  ...    8479973     Stuart Skinner
# 4            5       58      -22  ...    8476945  Connor Hellebuyck
#
#    shot_type zone    shot_class position shooter_hand shooting_pct glove_hand  \
# 0      wrist    O  shot-on-goal        C            R       0.1728          L
# 1       snap    O   missed-shot        D            L       0.0634          L
# 2     tip-in    O  shot-on-goal        R            R       0.1037          L
# 3       snap    O  shot-on-goal        C            L       0.1164          L
# 4       snap    O  shot-on-goal        C            L       0.1856          L
#
#    save_pct
# 0   0.90529
# 1   0.90529
# 2   0.91754
# 3   0.90529
# 4   0.91754
#
# [5 rows x 22 columns]

# %%
from src.scraper import get_skater_stats

# %%
complete_df = get_skater_stats(shots_2025)

# %%
complete_df.head()
# Out:
#       game_id  team_id  home     last_play  rebound  rush home_skaters  \
# 0  2024020008       52     0           hit        0     0            5
# 1  2024020008       52     0       faceoff        0     0            5
# 2  2024020008       22     1           hit        0     0            5
# 3  2024020008       52     0  shot-on-goal        0     0            5
# 4  2024020008       22     1       faceoff        0     0            5
#
#   away_skaters  x_coord  y_coord  ...  goalie_id             goalie  \
# 0            5       70        4  ...    8479973     Stuart Skinner
# 1            5       54      -21  ...    8479973     Stuart Skinner
# 2            5       68       -8  ...    8476945  Connor Hellebuyck
# 3            5       53      -31  ...    8479973     Stuart Skinner
# 4            5       58      -22  ...    8476945  Connor Hellebuyck
#
#    shot_type zone    shot_class position shooter_hand shooting_pct glove_hand  \
# 0      wrist    O  shot-on-goal        C            R       0.1728          L
# 1       snap    O   missed-shot        D            L       0.0634          L
# 2     tip-in    O  shot-on-goal        R            R       0.1037          L
# 3       snap    O  shot-on-goal        C            L       0.1164          L
# 4       snap    O  shot-on-goal        C            L       0.1856          L
#
#    save_pct
# 0   0.90529
# 1   0.90529
# 2   0.91754
# 3   0.90529
# 4   0.91754
#
# [5 rows x 22 columns]

# %%
complete_df["home_skaters"].value_counts()
# Out:
# home_skaters
# 5    176528
# 4     16244
# 3      2569
# 6      2402
# 1       456
# 0       432
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
complete_df.head()
# Out:
#       game_id  team_id  home     last_play  rebound  rush home_skaters  \
# 0  2024020008       52     0           hit        0     0            5
# 1  2024020008       52     0       faceoff        0     0            5
# 2  2024020008       22     1           hit        0     0            5
# 3  2024020008       52     0  shot-on-goal        0     0            5
# 4  2024020008       22     1       faceoff        0     0            5
#
#   away_skaters  x_coord  y_coord  shooter_id         shooter  goalie_id  \
# 0            5       70        4     8476460  Mark Scheifele    8479973
# 1            5       54      -21     8477504  Josh Morrissey    8479973
# 2            5       68       -8     8477015    Connor Brown    8476945
# 3            5       53      -31     8482149   Cole Perfetti    8479973
# 4            5       58      -22     8477934  Leon Draisaitl    8476945
#
#               goalie shot_type zone    shot_class position shooter_hand  \
# 0     Stuart Skinner     wrist    O  shot-on-goal        C            R
# 1     Stuart Skinner      snap    O   missed-shot        D            L
# 2  Connor Hellebuyck    tip-in    O  shot-on-goal        R            R
# 3     Stuart Skinner      snap    O  shot-on-goal        C            L
# 4  Connor Hellebuyck      snap    O  shot-on-goal        C            L
#
#    shooting_pct glove_hand  save_pct
# 0        0.1728          L   0.90529
# 1        0.0634          L   0.90529
# 2        0.1037          L   0.91754
# 3        0.1164          L   0.90529
# 4        0.1856          L   0.91754

# %%
# Every shot is plotted on one half of the ice, the red line is at x = 0, the blue line is at x = 25, goal line at x = 89, all measurements are in feet.
# Use this information to create an angle to the net feature
def angle(x_coord, y_coord):
    x_centered = 89 - x_coord
    return round(np.degrees(np.arctan(y_coord/x_centered)), 2)

complete_df['angles'] = angle(complete_df['x_coord'], complete_df['y_coord'])
complete_df.head()
# Out:
#       game_id  team_id  home     last_play  rebound  rush home_skaters  \
# 0  2024020008       52     0           hit        0     0            5
# 1  2024020008       52     0       faceoff        0     0            5
# 2  2024020008       22     1           hit        0     0            5
# 3  2024020008       52     0  shot-on-goal        0     0            5
# 4  2024020008       22     1       faceoff        0     0            5
#
#   away_skaters  x_coord  y_coord  shooter_id         shooter  goalie_id  \
# 0            5       70        4     8476460  Mark Scheifele    8479973
# 1            5       54      -21     8477504  Josh Morrissey    8479973
# 2            5       68       -8     8477015    Connor Brown    8476945
# 3            5       53      -31     8482149   Cole Perfetti    8479973
# 4            5       58      -22     8477934  Leon Draisaitl    8476945
#
#               goalie shot_type zone    shot_class position shooter_hand  \
# 0     Stuart Skinner     wrist    O  shot-on-goal        C            R
# 1     Stuart Skinner      snap    O   missed-shot        D            L
# 2  Connor Hellebuyck    tip-in    O  shot-on-goal        R            R
# 3     Stuart Skinner      snap    O  shot-on-goal        C            L
# 4  Connor Hellebuyck      snap    O  shot-on-goal        C            L
#
#    shooting_pct glove_hand  save_pct  angles
# 0        0.1728          L   0.90529   11.89
# 1        0.0634          L   0.90529  -30.96
# 2        0.1037          L   0.91754  -20.85
# 3        0.1164          L   0.90529  -40.73
# 4        0.1856          L   0.91754  -35.36

# %%
complete_df["shot_on_glove"] = complete_df["shooter_hand"] + complete_df["glove_hand"]

# %%
complete_df["home_skaters"] = complete_df["home_skaters"].astype(int)
complete_df["away_skaters"] = complete_df["away_skaters"].astype(int)
complete_df = complete_df[complete_df["home_skaters"] >= 3]
complete_df = complete_df[complete_df["away_skaters"] >= 3]

# %%
complete_df["home_skaters"].value_counts()
# Out:
# home_skaters
# 5    176528
# 4     16244
# 3      2569
# 6      2402
# Name: count, dtype: int64

# %%
complete_df["situation"] = complete_df.apply(
    lambda row: "EV" if row["home_skaters"] == row["away_skaters"] else
    ('PP' if row['home_skaters'] > row['away_skaters'] else 'SH'),
    axis=1
    )

# %%
complete_df["situation"].value_counts()
# Out:
# situation
# EV    162247
# PP     18544
# SH     16952
# Name: count, dtype: int64

# %%
complete_df.head()
# Out:
#       game_id  team_id  home     last_play  rebound  rush  home_skaters  \
# 0  2024020008       52     0           hit        0     0             5
# 1  2024020008       52     0       faceoff        0     0             5
# 2  2024020008       22     1           hit        0     0             5
# 3  2024020008       52     0  shot-on-goal        0     0             5
# 4  2024020008       22     1       faceoff        0     0             5
#
#    away_skaters  x_coord  y_coord  shooter_id         shooter  goalie_id  \
# 0             5       70        4     8476460  Mark Scheifele    8479973
# 1             5       54      -21     8477504  Josh Morrissey    8479973
# 2             5       68       -8     8477015    Connor Brown    8476945
# 3             5       53      -31     8482149   Cole Perfetti    8479973
# 4             5       58      -22     8477934  Leon Draisaitl    8476945
#
#               goalie shot_type zone    shot_class position shooter_hand  \
# 0     Stuart Skinner     wrist    O  shot-on-goal        C            R
# 1     Stuart Skinner      snap    O   missed-shot        D            L
# 2  Connor Hellebuyck    tip-in    O  shot-on-goal        R            R
# 3     Stuart Skinner      snap    O  shot-on-goal        C            L
# 4  Connor Hellebuyck      snap    O  shot-on-goal        C            L
#
#    shooting_pct glove_hand  save_pct  angles shot_on_glove situation
# 0        0.1728          L   0.90529   11.89            RL        EV
# 1        0.0634          L   0.90529  -30.96            LL        EV
# 2        0.1037          L   0.91754  -20.85            RL        EV
# 3        0.1164          L   0.90529  -40.73            LL        EV
# 4        0.1856          L   0.91754  -35.36            LL        EV

# %%
complete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 197743 entries, 0 to 198630
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   game_id        197743 non-null  int64
#  1   team_id        197743 non-null  int64
#  2   home           197743 non-null  int64
#  3   last_play      197743 non-null  object
#  4   rebound        197743 non-null  int64
#  5   rush           197743 non-null  int64
#  6   home_skaters   197743 non-null  int64
#  7   away_skaters   197743 non-null  int64
#  8   x_coord        197743 non-null  int64
#  9   y_coord        197743 non-null  int64
#  10  shooter_id     197743 non-null  int64
#  11  shooter        197743 non-null  object
#  12  goalie_id      197743 non-null  int64
#  13  goalie         197743 non-null  object
#  14  shot_type      197743 non-null  object
#  15  zone           197743 non-null  object
#  16  shot_class     197743 non-null  object
#  17  position       197743 non-null  object
#  18  shooter_hand   197743 non-null  object
#  19  shooting_pct   197721 non-null  float64
#  20  glove_hand     197743 non-null  object
#  21  save_pct       197743 non-null  float64
#  22  angles         197739 non-null  float64
#  23  shot_on_glove  197743 non-null  object
#  24  situation      197743 non-null  object
# dtypes: float64(3), int64(11), object(11)
# memory usage: 39.2+ MB

# %%
from src.scraper import get_processed_data

# %%
test_df = get_skater_stats(shots_2025)

# %%
processed_df = get_processed_data(test_df)

# %%
processed_df
# Out:
#         home     last_play     rebound     rush  home_skaters  away_skaters  \
# 0       Away           hit  No rebound  No rush             5             5
# 1       Away       faceoff  No rebound  No rush             5             5
# 2       Home           hit  No rebound  No rush             5             5
# 3       Away  shot-on-goal  No rebound  No rush             5             5
# 4       Home       faceoff  No rebound  No rush             5             5
# ...      ...           ...         ...      ...           ...           ...
# 198626  Home  shot-on-goal  No rebound  No rush             5             4
# 198627  Away           hit  No rebound  No rush             5             5
# 198628  Away  blocked-shot  No rebound  No rush             5             5
# 198629  Away      giveaway  No rebound  No rush             5             5
# 198630  Away  shot-on-goal  No rebound  No rush             5             5
#
#         x_coord  y_coord shot_type zone    shot_class position shooter_hand  \
# 0            70        4     wrist    O  shot-on-goal        C            R
# 1            54      -21      snap    O   missed-shot        D            L
# 2            68       -8    tip-in    O  shot-on-goal        R            R
# 3            53      -31      snap    O  shot-on-goal        C            L
# 4            58      -22      snap    O  shot-on-goal        C            L
# ...         ...      ...       ...  ...           ...      ...          ...
# 198626       62      -16     wrist    O          goal        C            R
# 198627       47       29      slap    O  shot-on-goal        D            R
# 198628       88       29     wrist    O   missed-shot        D            R
# 198629       71      -42     wrist    O  shot-on-goal        L            L
# 198630       63       36     wrist    O  shot-on-goal        D            R
#
#         shooting_pct glove_hand  save_pct  angle shot_on_glove situation  \
# 0             0.1726          L  0.905290  11.89            RL        EV
# 1             0.0633          L  0.905290 -30.96            LL        EV
# 2             0.1037          L  0.917598 -20.85            RL        EV
# 3             0.1187          L  0.905290 -40.73            LL        EV
# 4             0.1856          L  0.917598 -35.36            LL        EV
# ...              ...        ...       ...    ...           ...       ...
# 198626        0.5000          L  0.910698 -30.65            RL        PP
# 198627        0.0778          L  0.903763  34.62            RL        EV
# 198628        0.0778          L  0.903763  88.03            RL        EV
# 198629        0.0869          L  0.903763 -66.80            LL        EV
# 198630        0.0778          L  0.903763  54.16            RL        EV
#
#         target
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 198626       1
# 198627       0
# 198628       0
# 198629       0
# 198630       0
#
# [197743 rows x 20 columns]

# %%
df_2024 = get_skater_stats(shots_2024)

# %%
processed_2024 = get_processed_data(df_2024)

# %%
processed_2024
# Out:
#         home     last_play     rebound     rush  home_skaters  away_skaters  \
# 0       Away       faceoff  No rebound  No rush             5             5
# 1       Away  shot-on-goal     Rebound  No rush             5             5
# 2       Away  blocked-shot  No rebound  No rush             5             5
# 3       Away       faceoff  No rebound  No rush             5             5
# 4       Home           hit  No rebound  No rush             5             5
# ...      ...           ...         ...      ...           ...           ...
# 244553  Home       faceoff  No rebound  No rush             5             5
# 244554  Home  shot-on-goal     Rebound  No rush             5             5
# 244555  Home  shot-on-goal  No rebound  No rush             5             5
# 244556  Away       faceoff  No rebound  No rush             4             5
# 244557  Away   missed-shot  No rebound  No rush             4             5
#
#         x_coord  y_coord    shot_type zone    shot_class position  \
# 0            81      -26         snap    O  shot-on-goal        C
# 1            83       -5         snap    O  shot-on-goal        C
# 2            77       -5        wrist    O  shot-on-goal        R
# 3            56       -4    deflected    O   missed-shot        L
# 4            75       -6        wrist    O  shot-on-goal        L
# ...         ...      ...          ...  ...           ...      ...
# 244553       82       -1       tip-in    O  shot-on-goal        C
# 244554       84        2         poke    O  shot-on-goal        L
# 244555       88        3  wrap-around    O   missed-shot        L
# 244556       47      -19         slap    O   missed-shot        L
# 244557       72      -21        wrist    O          goal        L
#
#        shooter_hand  shooting_pct glove_hand  save_pct  angle shot_on_glove  \
# 0                 R        0.1821          L  0.908291 -72.90            RL
# 1                 R        0.1726          L  0.908291 -39.81            RL
# 2                 L        0.1250          L  0.908291 -22.62            LL
# 3                 L        0.1191          L  0.908291  -6.91            LL
# 4                 L        0.0785          L  0.917598 -23.20            LL
# ...             ...           ...        ...       ...    ...           ...
# 244553            L        0.0560          L  0.914286  -8.13            LL
# 244554            R        0.2053          L  0.914286  21.80            RL
# 244555            R        0.2053          L  0.914286  71.57            RL
# 244556            R        0.0974          L  0.905420 -24.34            RL
# 244557            R        0.0974          L  0.905420 -51.01            RL
#
#        situation  target
# 0             EV       0
# 1             EV       0
# 2             EV       0
# 3             EV       0
# 4             EV       0
# ...          ...     ...
# 244553        EV       0
# 244554        EV       0
# 244555        EV       0
# 244556        SH       0
# 244557        SH       1
#
# [243250 rows x 20 columns]

# %%
df_2023 = get_skater_stats(shots_2023)

# %%
processed_2023 = get_processed_data(df_2023)

# %%
processed_2023
# Out:
#         home     last_play     rebound     rush  home_skaters  away_skaters  \
# 0       Home      giveaway  No rebound     Rush             5             5
# 1       Home           hit  No rebound  No rush             5             5
# 2       Away  shot-on-goal  No rebound  No rush             5             5
# 3       Home           hit  No rebound  No rush             5             5
# 4       Home           hit  No rebound  No rush             5             5
# ...      ...           ...         ...      ...           ...           ...
# 243811  Home      giveaway  No rebound  No rush             5             5
# 243812  Away  shot-on-goal  No rebound  No rush             5             5
# 243813  Away   missed-shot  No rebound  No rush             5             5
# 243814  Away           hit  No rebound  No rush             5             5
# 243815  Home       faceoff  No rebound  No rush             5             5
#
#         x_coord  y_coord shot_type zone    shot_class position shooter_hand  \
# 0            77        6     wrist    O  shot-on-goal        C            L
# 1            30       30      slap    O  shot-on-goal        D            R
# 2            35       30     wrist    O  shot-on-goal        D            L
# 3            41       14     wrist    O  shot-on-goal        R            R
# 4            46       17     wrist    O  shot-on-goal        R            R
# ...         ...      ...       ...  ...           ...      ...          ...
# 243811       37      -27     wrist    D  shot-on-goal        D            R
# 243812       57       20     wrist    O   missed-shot        D            R
# 243813       82       11  backhand    O   missed-shot        C            L
# 243814       73      -13      snap    O  shot-on-goal        L            R
# 243815       43      -22     wrist    O  shot-on-goal        D            R
#
#         shooting_pct glove_hand  save_pct  angle shot_on_glove situation  \
# 0             0.0880          L  0.915213  26.57            LL        EV
# 1             0.0427          L  0.915213  26.95            RL        EV
# 2             0.0439          L  0.917598  29.05            LL        EV
# 3             0.1086          L  0.915213  16.26            RL        EV
# 4             0.1086          L  0.915213  21.57            RL        EV
# ...              ...        ...       ...    ...           ...       ...
# 243811        0.0116          L  0.909857 -27.44            RL        EV
# 243812        0.0344          L  0.905290  32.01            RL        EV
# 243813        0.0683          L  0.905290  57.53            LL        EV
# 243814        0.0974          L  0.905290 -39.09            RL        EV
# 243815        0.0427          L  0.909857 -25.56            RL        EV
#
#         target
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 243811       0
# 243812       0
# 243813       0
# 243814       0
# 243815       0
#
# [242418 rows x 20 columns]

# %%
path2025 = Path('..') / 'data' / 'processed' / 'processed_shots_2025.parquet'
path2024 = Path('..') / 'data' / 'processed' / 'processed_shots_2024.parquet'
path2023 = Path('..') / 'data' / 'processed' / 'processed_shots_2023.parquet'

# %%
processed_df.to_parquet(path=path2025, engine="pyarrow")
processed_2024.to_parquet(path=path2024, engine="pyarrow")
processed_2023.to_parquet(path=path2023, engine="pyarrow")
